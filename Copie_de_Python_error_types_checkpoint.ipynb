# %% [markdown]
# # Rectify the code in each cell and **explain the error in comments**

# %% [markdown]
# ### index error

# %%
mylist=[14, "hello", 967]
mylist[1]
#the index doesn't in mylist
# Out:
# 'hello'

# %%
import pandas
import numpy
#numpy and pandas weren't written correctly

# %% [markdown]
# # syntax error

# %%
print("python errors")
#les parentheses
# Out:
# python errors

# %% [markdown]
# # key error

# %%
mydictionnary={True:"hello",False:"bye", '3':"python"}
mydictionnary[1]
# Out:
# 'hello'

# %% [markdown]
# # indentation error

# %%
i=14
while i<78:
  print(i)
i+=1
break
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# ...

# %% [markdown]
# # StopIteration

# %%
it=iter([1,2,3])
next(it)
# Out:
# 1

# %% [markdown]
# # TypeError

# %%
15+15
# Out:
# 30

# %% [markdown]
# # ValueError

# %%
str('python')
# Out:
# 'python'

# %% [markdown]
# # NameError

# %%
python=5
python
# Out:
# 5

# %% [markdown]
# # ZeroDivisionError

# %%
x=19/2
x
# Out:
# 9
